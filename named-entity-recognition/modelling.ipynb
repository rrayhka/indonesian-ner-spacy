# %%
import spacy
import random
from spacy.training.example import Example
from spacy.util import minibatch, compounding
import json
with open('data_full.json', 'r', encoding='utf-8') as f:
    TRAIN_DATA = json.load(f)
nlp = spacy.blank("id")
ner = nlp.add_pipe("ner")
for item in TRAIN_DATA:
    for start, end, label in item['entities']:
        ner.add_label(label)
pipe_exceptions = ["ner", "trf_wordpiecer", "trf_tok2vec"]
unaffected_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]
with nlp.disable_pipes(*unaffected_pipes):
    optimizer = nlp.begin_training()
    for itn in range(300): 
        random.shuffle(TRAIN_DATA)
        losses = {}
        batches = minibatch(TRAIN_DATA, size=compounding(4.0, 32.0, 1.001))
        for batch in batches:
            examples = []
            for d in batch:
                doc = nlp.make_doc(d['text'])
                example = Example.from_dict(doc, {"entities": d['entities']})
                examples.append(example)
            nlp.update(examples, drop=0.5, losses=losses)
        print(f"Losses at iteration {itn}: {losses}")
nlp.to_disk("model")
print("Model saved to 'model'")
# Out:
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Gaya Jokowi blusukan pun dinilai Ruhut hanya penci..." with entities "[[4, 12, 'PERSON'], [33, 39, 'PERSON']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Partai atau siapa pun tidak perlu menekan, mendikt..." with entities "[[97, 103, 'PERSON'], [129, 137, 'ORGANIZATION']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Megajuga akan memperagakan kepada masyarakat untuk..." with entities "[[0, 4, 'PERSON'], [61, 71, 'PERSON']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text ""Ya sama dong.  Masak dibedakan," ujar Joko Widodo..." with entities "[[39, 50, 'PERSON'], [74, 80, 'PERSON'], [85, 123,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tiga nama kandidat capres dari PKB adalah Mahfud M..." with entities "[[31, 34, 'ORGANIZATION'], [42, 53, 'PERSON'], [55...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Meski demikian, Ruhut mengatakan tak ada masalah h..." with entities "[[16, 22, 'PERSON'], [73, 79, 'PERSON']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Terakhir, namanya dilaporkan Ketua Mahkamah Konsti..." with entities "[[55, 64, 'PERSON'], [92, 108, 'ORGANIZATION'], [1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Kejaksaan Agung beberapa waktu lalu merilis 10 nam..." with entities "[[44, 51, 'QUANTITY'], [109, 120, 'PERSON'], [135,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Setelah Komisi Pemilihan Umum (KPU) memutuskan Jok..." with entities "[[8, 35, 'ORGANIZATION'], [47, 58, 'PERSON'], [64,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Memang saat ditemui, siang tadi, Vena mengenakan p..." with entities "[[32, 37, 'PERSON']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Untuk calon wakil presiden (cawapres), Megawati su..." with entities "[[39, 47, 'PERSON'], [101, 129, 'PERSON'], [179, 1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Sebelum mendatangi acara Hari Ulang Tahun GP Ansor..." with entities "[[58, 69, 'PERSON'], [95, 130, 'LOCATION']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Namun, secara pribadi, Adnan menilai penggunaan ca..." with entities "[[23, 29, 'PERSON']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Mengenakan mobil dinas Toyota Crown RI36,  Jonan t..." with entities "[[23, 29, 'ORGANIZATION'], [36, 38, 'LOCATION'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Untuk menunjukkan dukungannya, Ruhut akan berkampa..." with entities "[[30, 36, 'PERSON'], [59, 65, 'PERSON'], [94, 108,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Mantan Ketua Mahkamah Konstitusi Mahfud Md.  bersi..." with entities "[[13, 32, 'ORGANIZATION'], [33, 44, 'PERSON'], [10...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Seharusnya, kata Demokrat, jika PKS komitmen denga..." with entities "[[17, 25, 'ORGANIZATION'], [32, 36, 'ORGANIZATION'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Mahfudz Siddiq Wasekjen Partai Keadilan Sejahtera ..." with entities "[[0, 14, 'PERSON'], [24, 55, 'ORGANIZATION'], [99,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Menanggapi keberatan tersebut, Haswandi menyatakan..." with entities "[[31, 40, 'PERSON']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Pasangan Joko Widodo-Jusuf Kalla dan KPU DKI Jakar..." with entities "[[9, 32, 'PERSON'], [36, 52, 'ORGANIZATION']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Selanjutnya,  Tontowi/ Lilyana akan berlaga di  In..." with entities "[[14, 21, 'PERSON'], [23, 30, 'PERSON'], [48, 57, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Bahkan Gubernur DKI Basuki Tjahaja Purnama (Ahok) ..." with entities "[[16, 19, 'LOCATION'], [20, 43, 'PERSON'], [44, 48...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Ketua Umum Demokrat Susilo Bambang Yudhoyono (SBY)..." with entities "[[20, 51, 'PERSON'], [94, 107, 'LOCATION']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Ketua Umum Partai Persatuan Pembangunan (PPP) hasi..." with entities "[[10, 45, 'ORGANIZATION'], [65, 74, 'LOCATION']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text ""Apakah majelis memberi kebijakan saksi pakai cada..." with entities "[[87, 96, 'LOCATION'], [201, 207, 'PERSON'], [209,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Partai Golkar berharap, proses pelaksanaan Pemilu ..." with entities "[[0, 14, 'ORGANIZATION']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text ""Yang prinsip bahwa PPP mendukung pemerintahan Jok..." with entities "[[20, 23, 'ORGANIZATION'], [64, 76, 'PERSON'], [11...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Sutan menjawab diplomatis, "Itu kan hak preogatif ..." with entities "[[0, 6, 'PERSON'], [72, 78, 'PERSON'], [91, 106, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Demikian disampaikan Direktur Indofood Thomas TjiE..." with entities "[[30, 38, 'ORGANIZATION'], [39, 49, 'PERSON'], [68...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text ""Yang LRT Jabodetabek sudah mulai, Jakartanya yang..." with entities "[[10, 21, 'LOCATION'], [35, 42, 'LOCATION'], [86, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Protes itu disampaikan Adnan kepada Ketua Majelis ..." with entities "[[23, 28, 'PERSON'], [42, 88, 'ORGANIZATION'], [89...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Partai Nasional Demokrat dan Partai Persatuan Pemb..." with entities "[[0, 24, 'ORGANIZATION'], [30, 57, 'ORGANIZATION']...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text ""Demokrat memang bukan partai yang pertama, tapi y..." with entities "[[1, 9, 'ORGANIZATION'], [69, 76, 'PERSON'], [93, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Ketika ditemui di sela sidang paripurna DPR RI di ..." with entities "[[51, 68, 'LOCATION'], [70, 88, 'TIME'], [90, 95, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Selain itu, dia juga menunggu bagaimana ketentuan ..." with entities "[[60, 76, 'ORGANIZATION']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text ""Saya keberatan Yang Mulia," ujar Neneng, diikuti ..." with entities "[[34, 40, 'PERSON'], [50, 59, 'PERSON'], [63, 71, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Menteri Tenaga Kerja dan Transmigrasi itu mengatak..." with entities "[[89, 96, 'PERSON']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Politikus Partai Demokrat Ruhut Sitompul mengataka..." with entities "[[9, 25, 'ORGANIZATION'], [26, 40, 'PERSON']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Kemudian, ada Ketua MA Harifin A Tumpa, Kapolri Ba..." with entities "[[23, 38, 'PERSON'], [49, 71, 'PERSON'], [83, 97, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Ia pun sempat mengatakan Jokowi tak pantas jadi pr..." with entities "[[24, 31, 'PERSON']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Komisi Nasional Hak Asasi Manusia mendorong agar k..." with entities "[[0, 34, 'ORGANIZATION'], [80, 91, 'PERSON']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text ""Kemarin saja ada kursi dari Demokrat yang dikuran..." with entities "[[29, 38, 'ORGANIZATION'], [78, 112, 'ORGANIZATION...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text ""Keputusan Presiden Jokowi yang mengajukan kembali..." with entities "[[20, 26, 'PERSON'], [96, 101, 'ORGANIZATION'], [1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Haswandi kemudian menanyakan ketiga saksi apakah b..." with entities "[[0, 9, 'PERSON']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Saat Jokowi menjadi Gubernur DKI Jakarta, Ruhut se..." with entities "[[5, 11, 'PERSON'], [29, 40, 'LOCATION'], [42, 48,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Losses at iteration 0: {'ner': 13967.142716713588}
# Losses at iteration 1: {'ner': 10546.598069934958}
# Losses at iteration 2: {'ner': 8770.66391412523}
# Losses at iteration 3: {'ner': 7673.624405408091}
# Losses at iteration 4: {'ner': 6981.402071063684}
# Losses at iteration 5: {'ner': 6455.0341658454}
# Losses at iteration 6: {'ner': 6132.434623955842}
# Losses at iteration 7: {'ner': 5896.302248239558}
# Losses at iteration 8: {'ner': 5588.071745699919}
# Losses at iteration 9: {'ner': 5446.760442979574}
# Losses at iteration 10: {'ner': 5193.543653198398}
# Losses at iteration 11: {'ner': 5051.165867038846}
# Losses at iteration 12: {'ner': 4928.54749017089}
# Losses at iteration 13: {'ner': 4814.373721709857}
# Losses at iteration 14: {'ner': 4713.375847702382}
# Losses at iteration 15: {'ner': 4533.689125210166}
# Losses at iteration 16: {'ner': 4379.505027068939}
# Losses at iteration 17: {'ner': 4272.329638794174}
# Losses at iteration 18: {'ner': 4304.534464695865}
# Losses at iteration 19: {'ner': 4155.747701082313}
# Losses at iteration 20: {'ner': 4101.20549986153}
# Losses at iteration 21: {'ner': 3980.208077339605}
# Losses at iteration 22: {'ner': 3956.850688077015}
# Losses at iteration 23: {'ner': 3868.2746137996487}
# Losses at iteration 24: {'ner': 3825.118706986332}
# Losses at iteration 25: {'ner': 3769.460953582783}
# Losses at iteration 26: {'ner': 3715.1367444907974}
# Losses at iteration 27: {'ner': 3639.891130399193}
# Losses at iteration 28: {'ner': 3571.1543490644162}
# Losses at iteration 29: {'ner': 3571.711033174743}
# Losses at iteration 30: {'ner': 3535.5902527149856}
# Losses at iteration 31: {'ner': 3487.217745157305}
# Losses at iteration 32: {'ner': 3440.37452852589}
# Losses at iteration 33: {'ner': 3400.40405273883}
# Losses at iteration 34: {'ner': 3407.6568479697917}
# Losses at iteration 35: {'ner': 3270.5020035395514}
# Losses at iteration 36: {'ner': 3243.7912181046345}
# Losses at iteration 37: {'ner': 3207.3560905993413}
# Losses at iteration 38: {'ner': 3252.862516246971}
# Losses at iteration 39: {'ner': 3221.5569060112443}
# Losses at iteration 40: {'ner': 3171.3456717980525}
# Losses at iteration 41: {'ner': 3100.43382124573}
# Losses at iteration 42: {'ner': 3081.2145145387117}
# Losses at iteration 43: {'ner': 3073.9421085720346}
# Losses at iteration 44: {'ner': 3092.996665625768}
# Losses at iteration 45: {'ner': 3070.9678204571637}
# Losses at iteration 46: {'ner': 3034.601620804859}
# Losses at iteration 47: {'ner': 2978.2693807908577}
# Losses at iteration 48: {'ner': 2957.7059803445945}
# Losses at iteration 49: {'ner': 2983.414198993921}
# Losses at iteration 50: {'ner': 2890.495134095871}
# Losses at iteration 51: {'ner': 2912.2828484694983}
# Losses at iteration 52: {'ner': 2890.342526275171}
# Losses at iteration 53: {'ner': 2775.8707058266905}
# Losses at iteration 54: {'ner': 2821.215060118198}
# Losses at iteration 55: {'ner': 2848.716924663744}
# Losses at iteration 56: {'ner': 2868.578454715915}
# Losses at iteration 57: {'ner': 2747.8531402890712}
# Losses at iteration 58: {'ner': 2749.982592088752}
# Losses at iteration 59: {'ner': 2731.7068065604894}
# Losses at iteration 60: {'ner': 2671.7998719213942}
# Losses at iteration 61: {'ner': 2746.0624853293534}
# Losses at iteration 62: {'ner': 2629.541299535913}
# Losses at iteration 63: {'ner': 2706.4877956440164}
# Losses at iteration 64: {'ner': 2697.4347729631845}
# Losses at iteration 65: {'ner': 2450.9969821549867}
# Losses at iteration 66: {'ner': 2582.687769252697}
# Losses at iteration 67: {'ner': 2612.3089763284092}
# Losses at iteration 68: {'ner': 2575.791277619366}
# Losses at iteration 69: {'ner': 2565.6437155562953}
# Losses at iteration 70: {'ner': 2503.8326980945317}
# Losses at iteration 71: {'ner': 2446.2295549319538}
# Losses at iteration 72: {'ner': 2437.6702845932864}
# Losses at iteration 73: {'ner': 2479.152336512613}
# Losses at iteration 74: {'ner': 2488.5957424308895}
# Losses at iteration 75: {'ner': 2498.1360739313986}
# Losses at iteration 76: {'ner': 2500.5928316408713}
# Losses at iteration 77: {'ner': 2516.4433828017713}
# Losses at iteration 78: {'ner': 2504.472040532375}
# Losses at iteration 79: {'ner': 2344.497926398704}
# Losses at iteration 80: {'ner': 2445.291009687616}
# Losses at iteration 81: {'ner': 2456.3246616998176}
# Losses at iteration 82: {'ner': 2477.0460104861772}
# Losses at iteration 83: {'ner': 2352.7017886537224}
# Losses at iteration 84: {'ner': 2358.9187071990395}
# Losses at iteration 85: {'ner': 2456.0459455759733}
# Losses at iteration 86: {'ner': 2407.530419176977}
# Losses at iteration 87: {'ner': 2371.0945983471856}
# Losses at iteration 88: {'ner': 2392.2773349546055}
# Losses at iteration 89: {'ner': 2421.920963884434}
# Losses at iteration 90: {'ner': 2389.9918176441242}
# Losses at iteration 91: {'ner': 2392.455432059296}
# Losses at iteration 92: {'ner': 2349.2401936605647}
# Losses at iteration 93: {'ner': 2344.071228452879}
# Losses at iteration 94: {'ner': 2343.539285600568}
# Losses at iteration 95: {'ner': 2280.1427482886274}
# Losses at iteration 96: {'ner': 2285.537886354993}
# Losses at iteration 97: {'ner': 2263.9983676255397}
# Losses at iteration 98: {'ner': 2322.9583354531655}
# Losses at iteration 99: {'ner': 2357.944270701557}
# Losses at iteration 100: {'ner': 2331.04193935173}
# Losses at iteration 101: {'ner': 2296.479533971764}
# Losses at iteration 102: {'ner': 2273.872292532818}
# Losses at iteration 103: {'ner': 2289.5909665640183}
# Losses at iteration 104: {'ner': 2164.17667335275}
# Losses at iteration 105: {'ner': 2186.1103993178544}
# Losses at iteration 106: {'ner': 2224.4621859970002}
# Losses at iteration 107: {'ner': 2269.3645824561822}
# Losses at iteration 108: {'ner': 2174.720195475441}
# Losses at iteration 109: {'ner': 2219.7850269358537}
# Losses at iteration 110: {'ner': 2276.0598293170156}
# Losses at iteration 111: {'ner': 2252.5186937557046}
# Losses at iteration 112: {'ner': 2199.336527873942}
# Losses at iteration 113: {'ner': 2184.904276125281}
# Losses at iteration 114: {'ner': 2202.1767622269626}
# Losses at iteration 115: {'ner': 2152.109243961498}
# Losses at iteration 116: {'ner': 2179.78433915312}
# Losses at iteration 117: {'ner': 2209.4537256932836}
# Losses at iteration 118: {'ner': 2173.5704041678814}
# Losses at iteration 119: {'ner': 2191.5153468628814}
# Losses at iteration 120: {'ner': 2089.585438135563}
# Losses at iteration 121: {'ner': 2150.0584177988985}
# Losses at iteration 122: {'ner': 2209.5217912118765}
# Losses at iteration 123: {'ner': 2257.3569819921195}
# Losses at iteration 124: {'ner': 2180.395413802215}
# Losses at iteration 125: {'ner': 2114.6499254011355}
# Losses at iteration 126: {'ner': 2116.9854866575365}
# Losses at iteration 127: {'ner': 2101.2106969376478}
# Losses at iteration 128: {'ner': 2113.4244694488757}
# Losses at iteration 129: {'ner': 2121.6887944184145}
# Losses at iteration 130: {'ner': 2062.6948634318182}
# Losses at iteration 131: {'ner': 2073.5836058226314}
# Losses at iteration 132: {'ner': 2151.551521198746}
# Losses at iteration 133: {'ner': 2103.669338374793}
# Losses at iteration 134: {'ner': 2033.5009280578818}
# Losses at iteration 135: {'ner': 2120.5189463856323}
# Losses at iteration 136: {'ner': 2082.160909257544}
# Losses at iteration 137: {'ner': 2101.0329120021224}
# Losses at iteration 138: {'ner': 2109.9797882737785}
# Losses at iteration 139: {'ner': 2020.588784026187}
# Losses at iteration 140: {'ner': 2056.406937040449}
# Losses at iteration 141: {'ner': 2106.6325262559317}
# Losses at iteration 142: {'ner': 2083.7444897139326}
# Losses at iteration 143: {'ner': 2110.6839958214905}
# Losses at iteration 144: {'ner': 2066.4226167300612}
# Losses at iteration 145: {'ner': 2015.3854871716055}
# Losses at iteration 146: {'ner': 1996.4106160691497}
# Losses at iteration 147: {'ner': 1992.3188649315136}
# Losses at iteration 148: {'ner': 2058.378813040696}
# Losses at iteration 149: {'ner': 1988.0528050262506}
# Losses at iteration 150: {'ner': 2027.9933427368428}
# Losses at iteration 151: {'ner': 2081.118036387416}
# Losses at iteration 152: {'ner': 2056.528354838226}
# Losses at iteration 153: {'ner': 2063.937788932806}
# Losses at iteration 154: {'ner': 2025.4034082336173}
# Losses at iteration 155: {'ner': 2006.0424141902959}
# Losses at iteration 156: {'ner': 2047.1834504153342}
# Losses at iteration 157: {'ner': 2026.5172466824604}
# Losses at iteration 158: {'ner': 1980.2977407371138}
# Losses at iteration 159: {'ner': 2081.0917216550815}
# Losses at iteration 160: {'ner': 2002.909891912593}
# Losses at iteration 161: {'ner': 2114.26774876627}
# Losses at iteration 162: {'ner': 2040.003627158031}
# Losses at iteration 163: {'ner': 2092.7956478784317}
# Losses at iteration 164: {'ner': 1957.0525386960105}
# Losses at iteration 165: {'ner': 1997.5927655553405}
# Losses at iteration 166: {'ner': 2016.8894590305695}
# Losses at iteration 167: {'ner': 2046.8739307918913}
# Losses at iteration 168: {'ner': 2022.130195601261}
# Losses at iteration 169: {'ner': 2015.7949758219404}
# Losses at iteration 170: {'ner': 2048.500730902933}
# Losses at iteration 171: {'ner': 2036.145585341453}
# Losses at iteration 172: {'ner': 1964.9565111156999}
# Losses at iteration 173: {'ner': 2009.768721724246}
# Losses at iteration 174: {'ner': 1956.2909485984917}
# Losses at iteration 175: {'ner': 1925.7092160421118}
# Losses at iteration 176: {'ner': 1938.2755409162262}
# Losses at iteration 177: {'ner': 1942.0498609273545}
# Losses at iteration 178: {'ner': 1946.3750458554828}
# Losses at iteration 179: {'ner': 2030.5583941642396}
# Losses at iteration 180: {'ner': 1925.7173307198027}
# Losses at iteration 181: {'ner': 1864.2246573563286}
# Losses at iteration 182: {'ner': 1947.2857536966906}
# Losses at iteration 183: {'ner': 2103.3393448166403}
# Losses at iteration 184: {'ner': 1856.63692015543}
# Losses at iteration 185: {'ner': 1853.5970857780244}
# Losses at iteration 186: {'ner': 1897.5227158835885}
# Losses at iteration 187: {'ner': 1978.354248323684}
# Losses at iteration 188: {'ner': 1915.578464619708}
# Losses at iteration 189: {'ner': 1958.3542377907945}
# Losses at iteration 190: {'ner': 1887.6331155558746}
# Losses at iteration 191: {'ner': 1955.1963632307954}
# Losses at iteration 192: {'ner': 1949.074713868883}
# Losses at iteration 193: {'ner': 1933.563747250954}
# Losses at iteration 194: {'ner': 1967.5426898821145}
# Losses at iteration 195: {'ner': 2038.8473396184513}
# Losses at iteration 196: {'ner': 1933.1696627709246}
# Losses at iteration 197: {'ner': 1865.0146955572695}
# Losses at iteration 198: {'ner': 1911.6833988111184}
# Losses at iteration 199: {'ner': 1905.3815196906744}
# Losses at iteration 200: {'ner': 1937.052447923007}
# Losses at iteration 201: {'ner': 1925.757093621191}
# Losses at iteration 202: {'ner': 1901.8571654282114}
# Losses at iteration 203: {'ner': 1917.1180371436421}
# Losses at iteration 204: {'ner': 1896.9561414059615}
# Losses at iteration 205: {'ner': 1921.6762121045567}
# Losses at iteration 206: {'ner': 1927.4208185425387}
# Losses at iteration 207: {'ner': 1925.3452729709613}
# Losses at iteration 208: {'ner': 1914.0034186402147}
# Losses at iteration 209: {'ner': 1851.8042650809207}
# Losses at iteration 210: {'ner': 1846.497907727247}
# Losses at iteration 211: {'ner': 1864.1292983144574}
# Losses at iteration 212: {'ner': 1933.5732358605012}
# Losses at iteration 213: {'ner': 1912.5914178953558}
# Losses at iteration 214: {'ner': 1891.5680726359415}
# Losses at iteration 215: {'ner': 1900.553424810336}
# Losses at iteration 216: {'ner': 1813.8806425991304}
# Losses at iteration 217: {'ner': 1882.0237928746324}
# Losses at iteration 218: {'ner': 1910.2480219871907}
# Losses at iteration 219: {'ner': 1852.096010096444}
# Losses at iteration 220: {'ner': 1935.291279179975}
# Losses at iteration 221: {'ner': 1945.095129611626}
# Losses at iteration 222: {'ner': 1799.9385416823138}
# Losses at iteration 223: {'ner': 1913.3377481073298}
# Losses at iteration 224: {'ner': 1818.8616890671126}
# Losses at iteration 225: {'ner': 1945.0850612987665}
# Losses at iteration 226: {'ner': 1867.2923500015593}
# Losses at iteration 227: {'ner': 1906.8446608676877}
# Losses at iteration 228: {'ner': 1933.71854859421}
# Losses at iteration 229: {'ner': 1832.6961624224048}
# Losses at iteration 230: {'ner': 1883.867673327274}
# Losses at iteration 231: {'ner': 1913.7607784970717}
# Losses at iteration 232: {'ner': 1775.4174055028084}
# Losses at iteration 233: {'ner': 1872.1654342870913}
# Losses at iteration 234: {'ner': 1891.8060561566745}
# Losses at iteration 235: {'ner': 1848.1231271934087}
# Losses at iteration 236: {'ner': 1930.0111577769158}
# Losses at iteration 237: {'ner': 1870.3986275966865}
# Losses at iteration 238: {'ner': 1910.86656178476}
# Losses at iteration 239: {'ner': 1958.2985078251716}
# Losses at iteration 240: {'ner': 1897.4424598103224}
# Losses at iteration 241: {'ner': 1852.6897912916704}
# Losses at iteration 242: {'ner': 1925.3830224979858}
# Losses at iteration 243: {'ner': 1852.9867850839385}
# Losses at iteration 244: {'ner': 1891.4911453941438}
# Losses at iteration 245: {'ner': 1902.1740439466107}
# Losses at iteration 246: {'ner': 1751.5835625544476}
# Losses at iteration 247: {'ner': 1937.1636528209779}
# Losses at iteration 248: {'ner': 1830.6625197117228}
# Losses at iteration 249: {'ner': 1876.8628982889252}
# Losses at iteration 250: {'ner': 1838.2162647129157}
# Losses at iteration 251: {'ner': 1868.9944852616538}
# Losses at iteration 252: {'ner': 1870.921303762243}
# Losses at iteration 253: {'ner': 1823.0897109961309}
# Losses at iteration 254: {'ner': 1825.8316491268206}
# Losses at iteration 255: {'ner': 1887.6603936852268}
# Losses at iteration 256: {'ner': 1817.8427774646977}
# Losses at iteration 257: {'ner': 1848.6558549084111}
# Losses at iteration 258: {'ner': 1833.6670121027896}
# Losses at iteration 259: {'ner': 1905.98489576667}
# Losses at iteration 260: {'ner': 1953.040001908254}
# Losses at iteration 261: {'ner': 1843.401311715212}
# Losses at iteration 262: {'ner': 1818.9224779119013}
# Losses at iteration 263: {'ner': 1877.740433371649}
# Losses at iteration 264: {'ner': 1865.907984399442}
# Losses at iteration 265: {'ner': 1938.0153075003398}
# Losses at iteration 266: {'ner': 1852.134995049141}
# Losses at iteration 267: {'ner': 1829.7041741885741}
# Losses at iteration 268: {'ner': 1915.6646916126726}
# Losses at iteration 269: {'ner': 1905.5924664139386}
# Losses at iteration 270: {'ner': 1918.2278530923147}
# Losses at iteration 271: {'ner': 1846.5165494494688}
# Losses at iteration 272: {'ner': 1825.7198191370544}
# Losses at iteration 273: {'ner': 1860.7435838682823}
# Losses at iteration 274: {'ner': 1867.2632394405646}
# Losses at iteration 275: {'ner': 1888.1704887250905}
# Losses at iteration 276: {'ner': 1805.9596831319816}
# Losses at iteration 277: {'ner': 1774.9078843437685}
# Losses at iteration 278: {'ner': 1781.464874398159}
# Losses at iteration 279: {'ner': 1859.5259064663192}
# Losses at iteration 280: {'ner': 1800.4446906299383}
# Losses at iteration 281: {'ner': 1867.5558790018622}
# Losses at iteration 282: {'ner': 1679.7526106186438}
# Losses at iteration 283: {'ner': 1880.6301126783237}
# Losses at iteration 284: {'ner': 1811.7382975138983}
# Losses at iteration 285: {'ner': 1826.208278806702}
# Losses at iteration 286: {'ner': 1945.641571161453}
# Losses at iteration 287: {'ner': 1855.8865266864761}
# Losses at iteration 288: {'ner': 1870.242723870591}
# Losses at iteration 289: {'ner': 1870.35334421862}
# Losses at iteration 290: {'ner': 1864.2524372516893}
# Losses at iteration 291: {'ner': 1807.7696887213651}
# Losses at iteration 292: {'ner': 1797.6888049055667}
# Losses at iteration 293: {'ner': 1918.7149170235557}
# Losses at iteration 294: {'ner': 1770.083926183069}
# Losses at iteration 295: {'ner': 1777.5844947186863}
# Losses at iteration 296: {'ner': 1855.0965136718064}
# Losses at iteration 297: {'ner': 1821.4568343966773}
# Losses at iteration 298: {'ner': 1797.5204016490652}
# Losses at iteration 299: {'ner': 1819.1094328246693}
# Model saved to 'model'

# %%
text = """
Keamanan dan perlindungan data menjadi isu hangat usai Pusat Data Nasional (PDN) diretas beberapa waktu lalu. Sehingga, semua pihak termasuk perusahaan Badan Usaha Milik Negara (BUMN) perlu mewaspadai serangan ransomware.
Staf Khusus Menteri BUMN Arya Sinulingga mengatakan, Menteri BUMN Erick Thohir meminta semua perusahaan pelat merah memperkuat sistem keamanannya.

"Kita dengan kejadian PDN Ini memang Pak Menteri juga meminta kita semua memperkuat keamanan sistemnya semua," ujarnya di Jakarta, Kamis (4/7/2024).
Perusahaan negara di semua sektor mulai dari sektor perbankan, PT Pertamina (Persero), Telkom, dan yang lainnya diminta untuk tidak meremehkan keamanan sistem data.

"Apa pun ceritanya keamanan siber ini penting dan ini kejadian walaupun kemarin kita tidak kena di BUMN tapi harus jadi peringatan bagi semua untuk memperkuat," sebutnya.

Menurutnya, backup data perlu dilakukan untuk mengantisipasi hal yang tidak diinginkan di kemudian hari. "Backup mandatori lah itu yang harus dilakukan BUMN supaya kalau ada apa apa bisa menggantikan dengan cepat," pungkasnya.

"""

doc = nlp(text)
print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
# Out:
# Entities [('Badan Usaha Milik Negara', 'ORGANIZATION'), ('BUMN', 'ORGANIZATION'), ('Arya Sinulingga', 'PERSON'), ('BUMN', 'ORGANIZATION'), ('Erick Thohir', 'PERSON'), ('Jakarta', 'LOCATION'), ('PT Pertamina (Persero)', 'ORGANIZATION'), ('Telkom', 'ORGANIZATION'), ('BUMN', 'ORGANIZATION'), ('BUMN', 'ORGANIZATION')]
